# %%
import pandas as pd
from pyprojroot import here

# %%
df = pd.read_csv(here("data/csv_xlsx/player.csv"))
df.head(3)
# Out:
#   LAST NAME OTHER NAMES        MOBILE PROMOTIONAL CONSENT           CREATED  \
# 0    KANKAM     JEFFREY  233245358341                   Y  9/19/22 10:24 AM
# 1   IBRAHIM    FATIMATU  233246661750                   N  9/19/22 10:24 AM
# 2     Yakah       Gifty  233249636525                   Y  9/19/22 10:24 AM
#
#    E- Score Indicative Segment  Gear  D301  D304  ...  D345  D346  D347  D348  \
# 0       244                  C     2    26     6  ...     6     4     9     2
# 1         4                  E     4     0     0  ...     0     0     0     0
# 2         1                  E     4     1     0  ...     0     0     0     0
#
#    D349  D350  D351  D352  D353  D354
# 0     2     1     3     0     1     0
# 1     0     0     0     0     0     0
# 2     0     0     0     0     0     0
#
# [3 rows x 58 columns]

# %%
print("player shape:", df.shape, "\n")
print("player columns:", df.columns, "\n")
print("player overview:", df.describe())
# Out:
# player shape: (361835, 58)
#
# player columns: Index(['LAST NAME', 'OTHER NAMES', 'MOBILE', 'PROMOTIONAL CONSENT', 'CREATED',
#        'E- Score', 'Indicative Segment', 'Gear', 'D301', 'D304', 'D307',
#        'D308', 'D309', 'D310', 'D311', 'D312', 'D313', 'D314', 'D315', 'D316',
#        'D317', 'D318', 'D319', 'D320', 'D321', 'D322', 'D323', 'D324', 'D325',
#        'D326', 'D327', 'D328', 'D329', 'D330', 'D331', 'D332', 'D333', 'D334',
#        'D335', 'D336', 'D337', 'D338', 'D339', 'D340', 'D341', 'D342', 'D343',
#        'D344', 'D345', 'D346', 'D347', 'D348', 'D349', 'D350', 'D351', 'D352',
#        'D353', 'D354'],
#       dtype='object')
#
# player overview:              MOBILE       E- Score           Gear           D301  \
# count  3.618350e+05  361835.000000  361835.000000  361835.000000
# mean   2.624721e+11       3.648566       3.920820       0.077488
# std    2.598276e+12      30.794998       0.392904       1.202662
# ...

# %% [markdown]
# what is the average E- Score for those who are Gear 4 ?

# %%
df[df["Gear"]==4]["E- Score"].mean()
# Out:
# 1.8070691420918568
